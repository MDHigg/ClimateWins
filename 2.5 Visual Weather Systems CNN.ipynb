# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Dense, BatchNormalization, Flatten, MaxPooling2D, Activation
from keras.layers.core import Dense, Dropout
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
#download the weather images and put them in a directory
path = r'C:\Users\Michael\Desktop\Career Foundry\03 Machine Learning\02 Real-World Applications of Machine Learning\2.05 Visual Applications\archive\Multi-class Weather Dataset'
folders = os.listdir(path)
print(folders)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %%
#this will load in the pictures and rescale them to 250x250pixels

datagenerator = ImageDataGenerator(rescale=1/255, validation_split=0.2)
train_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='training',
)

test_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='validation',
)
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %%
#this is a CNN to categorize the weather images

inputs = Input(shape=(250, 250, 3))

x = Conv2D(32, (5,5), activation = 'relu')(inputs)
x = MaxPooling2D(3,3)(x)
x = Conv2D(64, (5,5) , activation = 'relu')(x)
x = MaxPooling2D((3,3))(x)
x = Conv2D(128 , (5,5) , activation = 'relu')(x)
x = MaxPooling2D(3,3)(x)
x = Flatten()(x)
x = Dropout(0.5, seed = 5)(x)
x = Dense(128 , activation = 'relu')(x)

outputs = Dense(4, activation = 'softmax')(x)

model:Model = Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# # Training the Algorithm

# %% [markdown]
# ## 1 Epoch

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 1, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# 28/28 [==============================] - 42s 1s/step - loss: 0.1270 - accuracy: 0.5524 - val_loss: 0.1045 - val_accuracy: 0.6964

# %% [markdown]
# ## 5 Epochs

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 5, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# Epoch 1/5
# 28/28 [==============================] - 39s 1s/step - loss: 0.1044 - accuracy: 0.6444 - val_loss: 0.0814 - val_accuracy: 0.7679
# Epoch 2/5
# 28/28 [==============================] - 38s 1s/step - loss: 0.0681 - accuracy: 0.8205 - val_loss: 0.0925 - val_accuracy: 0.7723
# Epoch 3/5
# 28/28 [==============================] - 38s 1s/step - loss: 0.0562 - accuracy: 0.8665 - val_loss: 0.0955 - val_accuracy: 0.7723
# Epoch 4/5
# 28/28 [==============================] - 38s 1s/step - loss: 0.0591 - accuracy: 0.8481 - val_loss: 0.0779 - val_accuracy: 0.8080
# Epoch 5/5
# 28/28 [==============================] - 38s 1s/step - loss: 0.0436 - accuracy: 0.8953 - val_loss: 0.0765 - val_accuracy: 0.8170

# %% [markdown]
# ## 10 Epochs

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 10, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# Epoch 1/10
# 28/28 [==============================] - 39s 1s/step - loss: 0.0656 - accuracy: 0.8343 - val_loss: 0.0923 - val_accuracy: 0.7768
# Epoch 2/10
# 28/28 [==============================] - 37s 1s/step - loss: 0.0579 - accuracy: 0.8573 - val_loss: 0.0671 - val_accuracy: 0.8348
# Epoch 3/10
# 28/28 [==============================] - 37s 1s/step - loss: 0.0560 - accuracy: 0.8412 - val_loss: 0.0888 - val_accuracy: 0.7679
# Epoch 4/10
# 28/28 [==============================] - 40s 1s/step - loss: 0.0526 - accuracy: 0.8619 - val_loss: 0.0643 - val_accuracy: 0.8304
# Epoch 5/10
# 28/28 [==============================] - 37s 1s/step - loss: 0.0446 - accuracy: 0.8838 - val_loss: 0.0604 - val_accuracy: 0.8259
# Epoch 6/10
# 28/28 [==============================] - 38s 1s/step - loss: 0.0335 - accuracy: 0.9171 - val_loss: 0.0604 - val_accuracy: 0.8482
# Epoch 7/10
# ...

# %% [markdown]
# ## 20 Epochs

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 20, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# Epoch 1/20
# 28/28 [==============================] - 38s 1s/step - loss: 0.0384 - accuracy: 0.8964 - val_loss: 0.0706 - val_accuracy: 0.8348
# Epoch 2/20
# 28/28 [==============================] - 38s 1s/step - loss: 0.0344 - accuracy: 0.9125 - val_loss: 0.0603 - val_accuracy: 0.8438
# Epoch 3/20
# 28/28 [==============================] - 38s 1s/step - loss: 0.0335 - accuracy: 0.9160 - val_loss: 0.0541 - val_accuracy: 0.8571
# Epoch 4/20
# 28/28 [==============================] - 37s 1s/step - loss: 0.0258 - accuracy: 0.9344 - val_loss: 0.0620 - val_accuracy: 0.8482
# Epoch 5/20
# 28/28 [==============================] - 38s 1s/step - loss: 0.0247 - accuracy: 0.9367 - val_loss: 0.0520 - val_accuracy: 0.8616
# Epoch 6/20
# 28/28 [==============================] - 37s 1s/step - loss: 0.0317 - accuracy: 0.9114 - val_loss: 0.0481 - val_accuracy: 0.8616
# Epoch 7/20
# ...

# %% [markdown]
# ### Outputing Analysis of 20 Epochs Results

# %%
results = pd.DataFrame(model.history.history)

# %%
results[['loss','val_loss']].plot(title='Model Loss')
plt.savefig('./loss.png')

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy')
plt.savefig('./accuracy.png')

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))
# Out:
# Accuracy: 0.9677790403366089, Val_Accuracy: 0.8616071343421936
# Loss: 0.01285236980766058, Val_Loss: 0.053417932242155075

# %% [markdown]
# ## 50 Epochs

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 50, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size,
)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 42s 1s/step - loss: 0.0238 - accuracy: 0.9413 - val_loss: 0.0607 - val_accuracy: 0.8661
# Epoch 2/50
# 28/28 [==============================] - 41s 2s/step - loss: 0.0132 - accuracy: 0.9678 - val_loss: 0.0472 - val_accuracy: 0.8616
# Epoch 3/50
# 28/28 [==============================] - 46s 2s/step - loss: 0.0160 - accuracy: 0.9574 - val_loss: 0.0460 - val_accuracy: 0.8795
# Epoch 4/50
# 28/28 [==============================] - 44s 2s/step - loss: 0.0213 - accuracy: 0.9413 - val_loss: 0.0516 - val_accuracy: 0.8661
# Epoch 5/50
# 28/28 [==============================] - 43s 2s/step - loss: 0.0152 - accuracy: 0.9597 - val_loss: 0.0498 - val_accuracy: 0.8839
# Epoch 6/50
# 28/28 [==============================] - 44s 2s/step - loss: 0.0089 - accuracy: 0.9770 - val_loss: 0.0452 - val_accuracy: 0.8705
# Epoch 7/50
# ...

# %% [markdown]
# ## Outputing analysis of 50 Epochs Results

# %%
results = pd.DataFrame(model.history.history)

# %%
results[['loss','val_loss']].plot(title='Model Loss')
plt.savefig('./loss.png')

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy')
plt.savefig('./accuracy.png')

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))
# Out:
# Accuracy: 0.9746835231781006, Val_Accuracy: 0.8616071343421936
# Loss: 0.009401367045938969, Val_Loss: 0.05647006258368492

# %% [markdown]
# # Testing on Individual Photos
# ## and creating a confusion matrix of results

# %%
# collect n batches of images and display the confusion matrix for them.

class_names = ['Cloudy', 'Rain', 'Shine', 'Sunrise']
n = 10 #<--you can change the number of batches selected.

image_batch, classes_batch = next(test_generator)

for batch in range(n):
    temp = next(test_generator)
    image_batch = np.concatenate((image_batch, temp[0]))
    classes_batch = np.concatenate((classes_batch, temp[1]))

classes_batch = classes_batch
y_predict = model.predict(image_batch)

#Confusion matrix for training data
cm = confusion_matrix(y_pred = [np.argmax(x) for x in y_predict], y_true = [np.argmax(x) for x in classes_batch])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.xticks([0, 1, 2, 3], class_names, rotation=90)
plt.yticks([0, 1, 2, 3], class_names)
plt.show()
# Out:
# 11/11 [==============================] - 3s 235ms/step

# %% [markdown]
# ### Results are least accurate for 'Cloudy' weather, often classing it as 'Shine'. All other weather predition is very accurate.

# %%
#This function will display a number of random images as well as the predictions for the type of weather.

def predict_one(model, num_images = None):  
    image_batch, classes_batch = next(test_generator)
    predicted_batch = model.predict(image_batch)
    for k in range(0,image_batch.shape[0] if num_images is None else num_images):
        image = image_batch[k]
        real_class = class_names[np.argmax(classes_batch[k])]
        predicted_class = class_names[np.argmax(predicted_batch[k])]
        value_predicted = predicted_batch[k]
        isTrue = (real_class == predicted_class)
        plt.figure(k)
        plt.title(str("Correct Prediction" if isTrue else "Incorrect Prediction") + ' - class: ' + real_class + ' - ' + 'predicted: ' + predicted_class + str(value_predicted))
        plt.axis('off')
        plt.savefig('./' + real_class + '_' + predicted_class + '_' + str(value_predicted) + '.png')
        plt.imshow(image)

# %%
predict_one(model, 1) #<--you can show multiple pictures with this command. Just fill in the number you want to see.
# Out:
# 1/1 [==============================] - 0s 279ms/step

# %% [markdown]
# # Accuracy and Loss

# %% [markdown]
# | Epochs | Accuracy | Val Accuracy | Notes |
# | :- | :- | :- | :- |
# | 1 | 0.5524 | 0.6964  | |
# | 5 | 0.8953 | 0.8170 | |
# | 10 | 0.9160 | 0.8750 | These results are the closest to one another |
# | 20 | 0.9678 | 0.8616 | 19th Epoch was slightly better |
# | 50 | 0.9747  | 0.8616 | Peaks Epoch 47; accuracy: 0.9954; val_accuracy: 0.8795 |

# %% [markdown]
# # GANs in Weather Prediction

# %% [markdown]
# 1. Analysis satellite photos to identify weather types in different regions
# 2. Style transfer - adapting one image to have the asthetics of a different weather type (this could be used for example in outdoor photoshoots where the weather on a particular day does not match the photographer's requirements)
# LINK: https://arxiv.org/abs/2103.05422#:~:text=To%20address%20this%20problem%2C%20we,%2C%20foggy%2C%20rainy%20and%20snowy.
#
# 3.  Looking at heat maps to predict extreem weather events. LINK:
# https://blog.research.google/2024/03/generative-ai-to-quantify-uncertainty.html#:~:text=SEEDS%20is%20a%20generative%20AI,traditional%20physics%2Dbased%20forecasting%20models.
